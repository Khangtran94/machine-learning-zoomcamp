# %% [markdown]
# ### Khang Tran Homework 05 Deployment

# %% [markdown]
# ### Question 1
#
# * Install `uv`
# * What's the version of uv you installed?
# * Use `--version` to find out

# %%
# !uv --version
# Out:
# uv 0.9.4

# %%
pwd
# Out:
# '/workspaces/machine-learning-zoomcamp/Khang_Tran_HW/Week_5_Deployment'

# %% [markdown]
# ### Question 2
#
# * Use uv to install Scikit-Learn version 1.6.1
# * What's the first hash for Scikit-Learn you get in the lock file?
# * Include the entire string starting with sha256:, don't include quotes
#
# Check from uv.lock

# %% [markdown]
# ### Question 3

# %%
import pickle
with open('pipeline_v1.bin', 'rb') as f_in:
    (dv, model) = pickle.load(f_in)
model
# Out:
# LogisticRegression(solver='liblinear')

# %%
data = {"lead_source": "paid_ads",
    "number_of_courses_viewed": 2,
    "annual_income": 79276.0}

X = dv.transform(data)
round(float(model.predict_proba(X)[0,1]),3)
# Out:
# 0.534

# %% [markdown]
# ### Question 4
#
# Now let's serve this model as a web service
#
# * Install FastAPI
# * Write FastAPI code for serving the model

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Check the UI:
# ![image.png](attachment:image.png)

# %% [markdown]
# Create Test_predict.py then try predict by 2 ways.
#
# client = {
#     "lead_source": "organic_search",
#     "number_of_courses_viewed": 4,
#     "annual_income": 80304.0
# }
#
# Option 1: via Terminal
# ![image.png](attachment:image.png)
#
# Option 2: via UI
# ![image-2.png](attachment:image-2.png)
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# ## Docker
# ### Question 5: Size of this base image
# ![image.png](attachment:image.png)

# %% [markdown]
# ### Dockerfile
# Create Dockerfile then
#
# docker build -t web-model-app . to build image
#
# docker run -p 8000:8000 web-model-app to run image
#
# docker ps: to check image
#
# docker stop $(docker ps -q): stop all
