# %% [markdown]
# ### Khang Tran Homework 10 Kubernetes

# %% [markdown]
# Go to the course-zoomcamp/cohorts/2025/05-deployment/homework folder and execute the following:
#
# ```python
# docker build -f Dockerfile_full -t zoomcamp-model:3.13.10-hw10 .
# ```

# %% [markdown]
# ## Question 1:
# Run tot test locally
# ```python
# docker run -it --rm -p 9696:9696 zoomcamp-model:3.13.10-hw10
# ```
# ![alt text](<Screenshot 2025-12-18 at 22.44.03.png>)
#
# * 0.29
# * 0.49
# * 0.69
# * 0.89
#
# ## Question 2:
# Kind version
# ![alt text](<Screenshot 2025-12-18 at 22.51.02.png>)
#
# ## Question 3:
#
# Smallest deployable computing unit
#
# * Node
# * Pod
# * Deployment
# * Service
#
# ## Question 4:
# Type of service already running
# ```python
# kubectl get services
# ```
# ![alt text](<Screenshot 2025-12-18 at 22.58.14.png>)
#
# ## Question 5:
# kind command to register docker images
#
# * kind create cluster
# * kind build node-image
# * kind load docker-image
# * kubectl apply
#
# ## Question 6:
# Create deployment.yaml
# then Replace <Image>, <Memory>, <CPU>, <Port> with the correct values.]
#
# ## Question 7:
# Create service.yaml
